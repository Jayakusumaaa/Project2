# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv ('Hujan.csv', sep=';')

# %%
dataset.head(5)
# Out:
#               FID,fid,the_geom,Id,Nm_Kec,Curah_Hujan
# 0  Hujan.1,1,"MULTIPOLYGON (((116.75085549799195 ...
# 1  Hujan.2,2,"MULTIPOLYGON (((116.74904825896884 ...
# 2  Hujan.3,3,"MULTIPOLYGON (((116.75575242607552 ...
# 3  Hujan.4,4,"MULTIPOLYGON (((116.748009105413 -1...
# 4  Hujan.5,5,"MULTIPOLYGON (((116.74736219727362 ...

# %%
sns.barplot(x='Nm_Kec', y='Curah_Hujan', data=data, width=0.25)
plt.xticks(rotation=90)  # Untuk memutar label sumbu x agar tidak tumpang tindih
plt.xlabel('Nama Kecamatan')
plt.ylabel('Curah Hujan')
plt.title('Visualisasi Curah Hujan per Kecamatan')
plt.show()

# %%
top_kecamatan = (data.groupby('Nm_Kec')['Curah_Hujan']
                    .sum()
                    .reset_index()
                    .sort_values(by='Curah_Hujan', ascending=False)
                    .head(5))
print(top_kecamatan)

data['kecamatan_top'] = data['Nm_Kec'].apply(lambda x: x if (x in top_kecamatan['Nm_Kec'].to_list()) else 'other')

plt.plot(data['Nm_Kec'], data['Curah_Hujan'])
plt.plot(data['Nm_Kec'], data['Curah_Hujan']*2)
plt.plot(data['Nm_Kec'], data['Curah_Hujan']*0.5)  # Garis tambahan
plt.xticks(rotation=90)
plt.xlabel('Kecamatan')
plt.ylabel('Curah Hujan')
plt.title('Visualisasi Curah Hujan per Kecamatan')
plt.legend(['Curah Hujan', 'Curah Hujan x 2', 'Curah Hujan x 3'])

plt.show()
# Out:
#         Nm_Kec  Curah_Hujan
# 4  Kecamatan 5           90
# 3  Kecamatan 4           80
# 2  Kecamatan 3           70
# 1  Kecamatan 2           60
# 0  Kecamatan 1           50
